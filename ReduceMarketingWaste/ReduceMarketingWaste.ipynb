# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv("dataset/train.csv")
test=pd.read_csv("dataset/test.csv")

# %%
print(train.shape)
# Out:
# (7007, 23)

# %%
train.head()
# Out:
#    Deal_title                      Lead_name               Industry  \
# 0  TitleM5DZY  Davis, Perkins and Bishop Inc            Restaurants
# 1  TitleKIW18                 Bender PLC LLC  Construction Services
# 2  TitleFXSDN          Carter-Henry and Sons      Hospitals/Clinics
# 3  TitlePSK4Y                 Garcia Ltd Ltd            Real Estate
# 4  Title904GV               Lee and Sons PLC     Financial Services
#
#    Deal_value  Weighted_amount Date_of_creation      Pitch  \
# 0    320506.0        2067263.7        3/29/2020  Product_2
# 1     39488.0         240876.8        7/10/2019  Product_2
# 2    359392.0        2407926.4        7/27/2019  Product_1
# 3     76774.0         468321.4        1/30/2021  Product_2
# 4    483896.0              NaN        5/22/2019  Product_2
#
#              Contact_no             Lead_revenue Fund_category  ...  \
# 0          607.447.7883         50 - 100 Million    Category 2  ...
# ...

# %%
test.head()
# Out:
#    Deal_title                       Lead_name                   Industry  \
# 0  TitleAD16O                 Bonilla Ltd Inc  Investment Bank/Brokerage
# 1  TitleOW6CR  Williams, Rogers and Roach PLC                Electronics
# 2  TitleVVJQ5    Wood, Vaughn and Morales Ltd                      Banks
# 3  TitleUS8NA             Durham-Crawford Inc                      Music
# 4  Title5VGWW    Simpson, Duncan and Long LLC                Real Estate
#
#    Deal_value  Weighted_amount Date_of_creation      Pitch  \
# 0    200988.0              NaN       2020-04-15  Product_1
# 1    409961.0       2541758.20       2021-01-23  Product_1
# 2    434433.0       3041031.00       2020-07-19  Product_1
# 3    218952.0       1521716.40       2020-02-27  Product_2
# 4    392835.0       2455218.75       2020-10-25  Product_1
#
#               Contact_no             Lead_revenue Fund_category  ...  \
# 0       167.332.2751x989        100 - 500 Million    Category 4  ...
# ...

# %%
#DATA PREPROCESSING

# %%
for i in train['Deal_value']:
    print(i)
# Out:
# 320506.0
# 39488.0
# 359392.0
# 76774.0
# 483896.0
# 418674.0
# 384356.0
# 245205.0
# 343280.0
# 293611.0
# 311125.0
# 7819.0
# 222331.0
# 487351.0
# 88552.0
# 85702.0
# 390309.0
# 140949.0
# 121705.0
# 420144.0
# 5338.0
# 55373.0
# 457687.0
# 207335.0
# 150607.0
# 164309.0
# 124235.0
# 380817.0
# 78985.0
# 59557.0
# 320881.0
# 482824.0
# 371548.0
# 335694.0
# 340613.0
# 216892.0
# 110031.0
# 252678.0
# 410369.0
# 365056.0
# 464364.0
# 122503.0
# 92852.0
# 8612.0
# 285382.0
# 456685.0
# 463865.0
# 67300.0
# 376485.0
# 332149.0
# 411909.0
# 457274.0
# 428962.0
# 438399.0
# 420368.0
# 393530.0
# 86291.0
# 76029.0
# 274931.0
# 487656.0
# 102240.0
# 406960.0
# 47786.0
# 300297.0
# 162873.0
# 58778.0
# 439832.0
# 244934.0
# 8343.0
# 408295.0
# 112933.0
# 396541.0
# 464395.0
# 123349.0
# 308373.0
# 14553.0
# 194795.0
# 100868.0
# 320859.0
# 356589.0
# 96066.0
# 397714.0
# 58529.0
# 39768.0
# 326944.0
# 289402.0
# 20372.0
# 268413.0
# 103466.0
# 145215.0
# 353308.0
# 27189.0
# 140037.0
# ...

# %%
len(train.axes[1])
# Out:
# 23

# %%
len(train.axes[0])
# Out:
# 7007

# %%
train.isna().sum()
# Out:
# Deal_title                 0
# Lead_name                  0
# Industry                   1
# Deal_value                51
# Weighted_amount          525
# Date_of_creation           0
# Pitch                      0
# Contact_no                 0
# Lead_revenue               0
# Fund_category              0
# Geography                972
# Location                  11
# POC_name                   0
# Designation                0
# Lead_POC_email             0
# Hiring_candidate_role      0
# Lead_source                0
# Level_of_meeting           1
# Last_lead_update         632
# Internal_POC               0
# Resource                 149
# Internal_rating            0
# Success_probability        6
# dtype: int64

# %%
test.isna().sum()
# Out:
# Deal_title                 0
# Lead_name                  0
# Industry                   1
# Deal_value                 5
# Weighted_amount           60
# Date_of_creation           0
# Pitch                      0
# Contact_no                 0
# Lead_revenue               0
# Fund_category              0
# Geography                 79
# Location                   3
# POC_name                   2
# Designation                0
# Lead_POC_email             0
# Hiring_candidate_role      0
# Lead_source                0
# Level_of_meeting           0
# Last_lead_update         168
# Internal_POC               0
# Resource                  14
# Internal_rating            0
# dtype: int64

# %%
train['Deal_value']=train.Deal_value.apply(lambda x: str(x).replace('$',''))
train['Weighted_amount']=train['Weighted_amount'].apply(lambda x: str(x).replace('$',''))
test['Deal_value']=test.Deal_value.apply(lambda x: str(x).replace('$',''))
test['Weighted_amount']=test['Weighted_amount'].apply(lambda x: str(x).replace('$',''))

# %%
for i in train['Deal_value']:
    print(i)
# Out:
# 320506.0
# 39488.0
# 359392.0
# 76774.0
# 483896.0
# 418674.0
# 384356.0
# 245205.0
# 343280.0
# 293611.0
# 311125.0
# 7819.0
# 222331.0
# 487351.0
# 88552.0
# 85702.0
# 390309.0
# 140949.0
# 121705.0
# 420144.0
# 5338.0
# 55373.0
# 457687.0
# 207335.0
# 150607.0
# 164309.0
# 124235.0
# 380817.0
# 78985.0
# 59557.0
# 320881.0
# 482824.0
# 371548.0
# 335694.0
# 340613.0
# 216892.0
# 110031.0
# 252678.0
# 410369.0
# 365056.0
# 464364.0
# 122503.0
# 92852.0
# 8612.0
# 285382.0
# 456685.0
# 463865.0
# 67300.0
# 376485.0
# 332149.0
# 411909.0
# 457274.0
# 428962.0
# 438399.0
# 420368.0
# 393530.0
# 86291.0
# 76029.0
# 274931.0
# 487656.0
# 102240.0
# 406960.0
# 47786.0
# 300297.0
# 162873.0
# 58778.0
# 439832.0
# 244934.0
# 8343.0
# 408295.0
# 112933.0
# 396541.0
# 464395.0
# 123349.0
# 308373.0
# 14553.0
# 194795.0
# 100868.0
# 320859.0
# 356589.0
# 96066.0
# 397714.0
# 58529.0
# 39768.0
# 326944.0
# 289402.0
# 20372.0
# 268413.0
# 103466.0
# 145215.0
# 353308.0
# 27189.0
# 140037.0
# ...

# %%
for i in train['Weighted_amount']:
    print(i)
# Out:
# 2067263.7
# 240876.8
# 2407926.4
# 468321.4
# nan
# 2637646.2
# 2709709.8
# 1642873.5
# 1991024.0
# 1791027.1
# 1851193.75
# 45741.15
# 1400685.3
# nan
# 562305.2
# 548492.8
# 2458946.7
# nan
# 760656.25
# 2730936.0
# 33362.5
# 343312.6
# 3020734.2
# nan
# 1001536.55
# 977638.55
# 751621.75
# 2513392.2
# 505504.0
# 330541.35
# 2278255.1
# 2945226.4
# 2173555.8
# nan
# 1958524.75
# 1344730.4
# 687693.75
# 1692942.6
# 2544287.8
# 2318105.6
# 3273766.2
# 698267.1
# 580325.0
# 52102.6
# 1826444.8
# 3105458.0
# 2899156.25
# nan
# 2560098.0
# 2075931.25
# 2471454.0
# 2972281.0
# 2573772.0
# 2981113.2
# 2480171.2
# 2518592.0
# 569520.6
# 478982.7
# 1677079.1
# 3169764.0
# 623664.0
# 2746980.0
# 255655.1
# 1861841.4
# 952807.05
# 405568.2
# nan
# 1616564.4
# 43800.75
# 2633502.75
# 700184.6
# 2379246.0
# 2972128.0
# 826438.3
# 2035261.8
# nan
# nan
# 615294.8
# 1925154.0
# 2353487.4
# 557182.8
# 2704455.2
# 380438.5
# 222700.8
# 2190524.8
# nan
# 131399.4
# 1758105.15
# 719088.7
# nan
# ...

# %%
train['Deal_value'] = train['Deal_value'].astype(float)
train['Weighted_amount'] = train['Weighted_amount'].astype(float)
test['Deal_value'] = test['Deal_value'].astype(float)
test['Weighted_amount'] = test['Weighted_amount'].astype(float)
#train['Industry'] = train['Industry'].astype(str)
#train['Geography'] = train['Geography'].astype(str)

# %%
train['Deal_value'].isna().sum()
# Out:
# 51

# %%
train['Weighted_amount'].isna().sum()
# Out:
# 525

# %%
train['Deal_value']=train['Deal_value'].fillna(train['Deal_value'].mean())
train['Weighted_amount']=train['Weighted_amount'].fillna(train['Weighted_amount'].mean())
train['Success_probability']=train['Success_probability'].fillna(train['Success_probability'].mean())
test['Deal_value']=test['Deal_value'].fillna(test['Deal_value'].mean())
test['Weighted_amount']=test['Weighted_amount'].fillna(test['Weighted_amount'].mean())

# %%
for i in train['Weighted_amount']:
    print(i)
# Out:
# 2067263.7
# 240876.8
# 2407926.4
# 468321.4
# 1569883.6682813931
# 2637646.2
# 2709709.8
# 1642873.5
# 1991024.0
# 1791027.1
# 1851193.75
# 45741.15
# 1400685.3
# 1569883.6682813931
# 562305.2
# 548492.8
# 2458946.7
# 1569883.6682813931
# 760656.25
# 2730936.0
# 33362.5
# 343312.6
# 3020734.2
# 1569883.6682813931
# 1001536.55
# 977638.55
# 751621.75
# 2513392.2
# 505504.0
# 330541.35
# 2278255.1
# 2945226.4
# 2173555.8
# 1569883.6682813931
# 1958524.75
# 1344730.4
# 687693.75
# 1692942.6
# 2544287.8
# 2318105.6
# 3273766.2
# 698267.1
# 580325.0
# 52102.6
# 1826444.8
# 3105458.0
# 2899156.25
# 1569883.6682813931
# 2560098.0
# 2075931.25
# 2471454.0
# 2972281.0
# 2573772.0
# 2981113.2
# 2480171.2
# 2518592.0
# 569520.6
# 478982.7
# 1677079.1
# 3169764.0
# 623664.0
# 2746980.0
# 255655.1
# 1861841.4
# 952807.05
# 405568.2
# 1569883.6682813931
# 1616564.4
# 43800.75
# 2633502.75
# 700184.6
# 2379246.0
# 2972128.0
# 826438.3
# 2035261.8
# 1569883.6682813931
# 1569883.6682813931
# ...

# %%
train['Deal_value']=train['Deal_value'].round(decimals=1)
train['Weighted_amount']=train['Weighted_amount'].round(decimals=1)
test['Deal_value']=test['Deal_value'].round(decimals=1)
test['Weighted_amount']=test['Weighted_amount'].round(decimals=1)

# %%
train['Success_probability'].dtypes
# Out:
# dtype('float64')

# %%
train
test
# Out:
#       Deal_title                        Lead_name                   Industry  \
# 0     TitleAD16O                  Bonilla Ltd Inc  Investment Bank/Brokerage
# 1     TitleOW6CR   Williams, Rogers and Roach PLC                Electronics
# 2     TitleVVJQ5     Wood, Vaughn and Morales Ltd                      Banks
# 3     TitleUS8NA              Durham-Crawford Inc                      Music
# 4     Title5VGWW     Simpson, Duncan and Long LLC                Real Estate
# ...          ...                              ...                        ...
# 2088  Title2R8VU    Phillips, Smith and Jones Inc              BioTech/Drugs
# 2089  Title7HCNJ              Elliott-Morales PLC                Real Estate
# 2090  TitleCD5YZ               Herrera-Santos PLC   Sales/Marketing Services
# 2091  Title8OKXL  Howard, Martinez and Jacobs PLC                      Banks
# 2092  TitleHFQT8                  Smith Group LLC   Architecture/Engineering
#
# ...

# %%
train['Industry'].mode()
test['Industry'].mode()
# Out:
# 0    Banks
# dtype: object

# %%
train.isna().sum()
# Out:
# Deal_title                 0
# Lead_name                  0
# Industry                   1
# Deal_value                 0
# Weighted_amount            0
# Date_of_creation           0
# Pitch                      0
# Contact_no                 0
# Lead_revenue               0
# Fund_category              0
# Geography                972
# Location                  11
# POC_name                   0
# Designation                0
# Lead_POC_email             0
# Hiring_candidate_role      0
# Lead_source                0
# Level_of_meeting           1
# Last_lead_update         632
# Internal_POC               0
# Resource                 149
# Internal_rating            0
# Success_probability        0
# dtype: int64

# %%
#train['Geography'] = train['Geography'].astype(str)

# %%
train['Geography'].isna().sum()
# Out:
# 972

# %%
train['Location'].mode()
# Out:
# 0    Aurangabad
# dtype: object

# %%
train['Last_lead_update'].mode()
# Out:
# 0    Following up but lead not responding
# dtype: object

# %%
train['Resource'].mode()
train['Level_of_meeting'].mode()
# Out:
# 0    Level 1
# dtype: object

# %%
train['Geography']=train.Geography.apply(lambda x: str(x).replace('nan','USA'))
train['Industry']=train['Industry'].apply(lambda x: str(x).replace('nan','Banks'))
train['Location']=train['Location'].apply(lambda x: str(x).replace('nan','Aurangabad'))
train['Last_lead_update']=train['Last_lead_update'].apply(lambda x: str(x).replace('nan','Following up but lead not responding'))
train['Resource']=train['Resource'].apply(lambda x: str(x).replace('nan','No'))
train['Level_of_meeting']=train.Level_of_meeting.apply(lambda x: str(x).replace('nan','Level 1'))



test['Geography']=test.Geography.apply(lambda x: str(x).replace('nan','USA'))
test['Industry']=test['Industry'].apply(lambda x: str(x).replace('nan','Banks'))
test['Location']=test['Location'].apply(lambda x: str(x).replace('nan','Aurangabad'))
test['Last_lead_update']=test['Last_lead_update'].apply(lambda x: str(x).replace('nan','Following up but lead not responding'))
test['Resource']=test['Resource'].apply(lambda x: str(x).replace('nan','No'))
test['Level_of_meeting']=test.Level_of_meeting.apply(lambda x: str(x).replace('nan','Level 1'))
test['POC_name']=test.POC_name.apply(lambda x: str(x).replace('nan','USA'))

# %%
train['Geography'].mode()
# Out:
# 0    USA
# dtype: object

# %%
train['Industry'].mode()
# Out:
# 0    Banks
# dtype: object

# %%
train['Geography'].isna().sum()
# Out:
# 0

# %%
for i in train['Geography']:
    print(i)
# Out:
# USA
# India
# USA
# USA
# India
# India
# USA
# USA
# USA
# USA
# USA
# USA
# USA
# USA
# India
# USA
# USA
# USA
# India
# India
# USA
# India
# India
# India
# USA
# India
# India
# USA
# India
# USA
# USA
# India
# India
# USA
# India
# USA
# USA
# USA
# USA
# USA
# India
# USA
# India
# USA
# India
# USA
# USA
# USA
# USA
# USA
# USA
# India
# India
# USA
# India
# India
# India
# USA
# USA
# India
# India
# USA
# India
# India
# USA
# India
# USA
# USA
# USA
# USA
# India
# India
# India
# USA
# USA
# India
# USA
# USA
# India
# India
# India
# USA
# India
# USA
# USA
# India
# USA
# India
# USA
# USA
# USA
# India
# USA
# USA
# India
# USA
# India
# India
# USA
# India
# India
# India
# India
# USA
# USA
# India
# USA
# India
# USA
# USA
# USA
# India
# India
# India
# India
# USA
# USA
# India
# USA
# USA
# India
# USA
# India
# India
# USA
# USA
# India
# India
# India
# India
# USA
# India
# USA
# USA
# USA
# USA
# USA
# India
# USA
# India
# USA
# USA
# USA
# India
# USA
# ...

# %%
train.isna().sum()
# Out:
# Deal_title               0
# Lead_name                0
# Industry                 0
# Deal_value               0
# Weighted_amount          0
# Date_of_creation         0
# Pitch                    0
# Contact_no               0
# Lead_revenue             0
# Fund_category            0
# Geography                0
# Location                 0
# POC_name                 0
# Designation              0
# Lead_POC_email           0
# Hiring_candidate_role    0
# Lead_source              0
# Level_of_meeting         0
# Last_lead_update         0
# Internal_POC             0
# Resource                 0
# Internal_rating          0
# Success_probability      0
# dtype: int64

# %%
test.isna().sum()
# Out:
# Deal_title               0
# Lead_name                0
# Industry                 0
# Deal_value               0
# Weighted_amount          0
# Date_of_creation         0
# Pitch                    0
# Contact_no               0
# Lead_revenue             0
# Fund_category            0
# Geography                0
# Location                 0
# POC_name                 0
# Designation              0
# Lead_POC_email           0
# Hiring_candidate_role    0
# Lead_source              0
# Level_of_meeting         0
# Last_lead_update         0
# Internal_POC             0
# Resource                 0
# Internal_rating          0
# dtype: int64

# %%
train.dtypes
# Out:
# Deal_title                object
# Lead_name                 object
# Industry                  object
# Deal_value               float64
# Weighted_amount          float64
# Date_of_creation          object
# Pitch                     object
# Contact_no                object
# Lead_revenue              object
# Fund_category             object
# Geography                 object
# Location                  object
# POC_name                  object
# Designation               object
# Lead_POC_email            object
# Hiring_candidate_role     object
# Lead_source               object
# Level_of_meeting          object
# Last_lead_update          object
# Internal_POC              object
# Resource                  object
# Internal_rating          float64
# Success_probability      float64
# dtype: object

# %%
train.head()
# Out:
#    Deal_title                      Lead_name               Industry  \
# 0  TitleM5DZY  Davis, Perkins and Bishop Inc            Restaurants
# 1  TitleKIW18                 Bender PLC LLC  Construction Services
# 2  TitleFXSDN          Carter-Henry and Sons      Hospitals/Clinics
# 3  TitlePSK4Y                 Garcia Ltd Ltd            Real Estate
# 4  Title904GV               Lee and Sons PLC   FiBankscial Services
#
#    Deal_value  Weighted_amount Date_of_creation      Pitch  \
# 0    320506.0        2067263.7        3/29/2020  Product_2
# 1     39488.0         240876.8        7/10/2019  Product_2
# 2    359392.0        2407926.4        7/27/2019  Product_1
# 3     76774.0         468321.4        1/30/2021  Product_2
# 4    483896.0        1569883.7        5/22/2019  Product_2
#
#              Contact_no             Lead_revenue Fund_category  ...  \
# 0          607.447.7883         50 - 100 Million    Category 2  ...
# ...

# %%
label_data1.dtypes
# Out:
# Deal_title                object
# Lead_name                 object
# Industry                  object
# Deal_value               float64
# Weighted_amount          float64
# Date_of_creation          object
# Pitch                     object
# Contact_no                object
# Lead_revenue              object
# Fund_category             object
# Geography                 object
# Location                  object
# POC_name                  object
# Designation               object
# Lead_POC_email            object
# Hiring_candidate_role     object
# Lead_source               object
# Level_of_meeting          object
# Last_lead_update          object
# Internal_POC              object
# Resource                  object
# Internal_rating          float64
# dtype: object

# %%
#encodeing all categorical var
s = (train.dtypes == 'object')


object_cols = list(s[s].index)

print(object_cols.pop(3))
print(object_cols.pop(4))


print("Categorical variables:")
print(object_cols)

from sklearn.preprocessing import LabelEncoder

# Make copy to avoid changing original data 
label_data = train.copy()

# Apply label encoder to each column with categorical data
label_encoder = LabelEncoder()
for col in object_cols:
    label_data[col] = label_encoder.fit_transform(train[col])
# Out:
# Date_of_creation
# Contact_no
# Categorical variables:
# ['Deal_title', 'Lead_name', 'Industry', 'Pitch', 'Lead_revenue', 'Fund_category', 'Geography', 'Location', 'POC_name', 'Designation', 'Lead_POC_email', 'Hiring_candidate_role', 'Lead_source', 'Level_of_meeting', 'Last_lead_update', 'Internal_POC', 'Resource']

# %%
train['POC_name'].mode()
# Out:
# 0    pooja
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
s1=(test.dtypes == 'object')
object_cols1 = list(s1[s1].index)
print(object_cols1.pop(3))
print(object_cols1.pop(4))
print(object_cols1)
label_data1=test.copy()
label_encoder = LabelEncoder()
for col in object_cols1:
    label_data1[col] = label_encoder.fit_transform(test[col])
# Out:
# Date_of_creation
# Contact_no
# ['Deal_title', 'Lead_name', 'Industry', 'Pitch', 'Lead_revenue', 'Fund_category', 'Geography', 'Location', 'POC_name', 'Designation', 'Lead_POC_email', 'Hiring_candidate_role', 'Lead_source', 'Level_of_meeting', 'Last_lead_update', 'Internal_POC', 'Resource']

# %%
label_data=label_data.drop(['Date_of_creation','Contact_no'],axis=1)
label_data1=label_data1.drop(['Date_of_creation','Contact_no'],axis=1)

# %%
label_data.dtypes
label_data1.dtypes
# Out:
# Deal_title                 int32
# Lead_name                  int32
# Industry                   int32
# Deal_value               float64
# Weighted_amount          float64
# Pitch                      int32
# Lead_revenue               int32
# Fund_category              int32
# Geography                  int32
# Location                   int32
# POC_name                   int32
# Designation                int32
# Lead_POC_email             int32
# Hiring_candidate_role      int32
# Lead_source                int32
# Level_of_meeting           int32
# Last_lead_update           int32
# Internal_POC               int32
# Resource                   int32
# Internal_rating          float64
# dtype: object

# %%
X1=label_data.iloc[:,:-1]
y1=label_data.iloc[:,-1]
y1=label_data.iloc[:,-1].astype(str)

# %%
#apply SelectKBest class to extract top 10 best features
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X1,y1)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X1.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))  #print 10 best features
# Out:
#                     Specs         Score
# 4         Weighted_amount  2.701637e+08
# 3              Deal_value  3.713463e+07
# 10               POC_name  1.921468e+06
# 0              Deal_title  3.228939e+05
# 1               Lead_name  3.027446e+05
# 12         Lead_POC_email  2.978000e+05
# 9                Location  2.973421e+04
# 13  Hiring_candidate_role  2.393130e+04
# 2                Industry  7.669312e+03
# 19        Internal_rating  7.464845e+03

# %%
#SPLIT THE DATASET INTO TRAIN AND TEST
X=label_data.iloc[:,np.r_[0:5,9,10,12,13,19]]
y=train.iloc[:,-1]

# %%
X.dtypes
y.dtypes
# Out:
# dtype('float64')

# %%
X_train=label_data.iloc[:,:-1]
y_train=train.iloc[:,-1]
X_test=label_data1.loc[:]

# %%
y_train
# Out:
# 0        73.60
# 1        58.90
# 2        68.80
# 3        64.50
# 4        62.40
#          ...
# 7002    107.34
# 7003     26.35
# 7004     70.60
# 7005     -5.00
# 7006     68.70
# Name: Success_probability, Length: 7007, dtype: float64

# %%
X_test
# Out:
#       Deal_title  Lead_name  Industry  Deal_value  Weighted_amount  Pitch  \
# 0            594        143        55    200988.0        1556916.7      0
# 1           1430       2012        30    409961.0        2541758.2      0
# 2           1843       2056        13    434433.0        3041031.0      0
# 3           1781        458        69    218952.0        1521716.4      1
# 4            332       1716        95    392835.0        2455218.8      0
# ...          ...        ...       ...         ...              ...    ...
# 2088         163       1440        16    417150.0        2732332.5      1
# 2089         424        473        95    488661.0        2956399.0      1
# 2090         712        805       103    421119.0        2631993.8      0
# 2091         496        850        13     59879.0         350292.2      0
# 2092        1011       1726         7    159677.0        1021932.8      0
#
#       Lead_revenue  Fund_category  Geography  Location  POC_name  Designation  \
# ...

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)
ev=regressor.predict(X_train)
y_pred.shape
# Out:
# (2093,)

# %%
df = pd.concat([test.Deal_title], axis=1)

# %%
test.Deal_title.shape
# Out:
# (2093,)

# %%
X_test.shape
# Out:
# (2093, 20)

# %%
y_train.shape
# Out:
# (7007,)

# %%
y_traindf=pd.DataFrame(y_train)

# %%
sf=pd.DataFrame(y_pred,columns=y_traindf.columns)

# %%
sf
# Out:
#       Success_probability
# 0               52.684960
# 1               61.630033
# 2               64.332833
# 3               61.491216
# 4               64.035382
# ...                   ...
# 2088            62.953030
# 2089            62.964366
# 2090            58.128561
# 2091            57.021288
# 2092            57.530899
#
# [2093 rows x 1 columns]

# %%
df = pd.concat([test.Deal_title,sf['Success_probability']], axis=1)

# %%
df
# Out:
#       Deal_title  Success_probability
# 0     TitleAD16O            52.684960
# 1     TitleOW6CR            61.630033
# 2     TitleVVJQ5            64.332833
# 3     TitleUS8NA            61.491216
# 4     Title5VGWW            64.035382
# ...          ...                  ...
# 2088  Title2R8VU            62.953030
# 2089  Title7HCNJ            62.964366
# 2090  TitleCD5YZ            58.128561
# 2091  Title8OKXL            57.021288
# 2092  TitleHFQT8            57.530899
#
# [2093 rows x 2 columns]

# %%
df.to_csv('predition.csv',index=False)

# %%
from sklearn.metrics import mean_squared_error
import math

# %%
y_train.shape
ev.shape
# Out:
# (7007,)

# %%
score = max(0, 100-np.sqrt(mean_squared_error(y_train,ev)))

# %%
score
# Out:
# 82.48473587753668
